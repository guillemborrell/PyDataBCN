# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
plt.style.use('bmh')
# %matplotlib notebook

# %%
path = os.path.join(os.curdir, 'data', 'winequality-white.xls')
wines = pd.read_excel(path)

# %%
wines
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36           20.70      0.045
# 1               6.3             0.300         0.34            1.60      0.049
# 2               8.1             0.280         0.40            6.90      0.050
# 3               7.2             0.230         0.32            8.50      0.058
# 4               7.2             0.230         0.32            8.50      0.058
# 5               8.1             0.280         0.40            6.90      0.050
# 6               6.2             0.320         0.16            7.00      0.045
# 7               7.0             0.270         0.36           20.70      0.045
# 8               6.3             0.300         0.34            1.60      0.049
# 9               8.1             0.220         0.43            1.50      0.044
# 10              8.1             0.270         0.41            1.45      0.033
# ...

# %%
wines.pH.describe()
# Out:
# count    4898.000000
# mean        3.188267
# std         0.151001
# min         2.720000
# 25%         3.090000
# 50%         3.180000
# 75%         3.280000
# max         3.820000
# Name: pH, dtype: float64

# %%
wines.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
wines.plot.scatter(x='fixed acidity', y='citric acid')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
wines.plot.hexbin(x='density', y='alcohol', gridsize=25)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
wines.plot.hexbin(x='quality', y='alcohol', gridsize=7)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
wines.corr()['quality']
# Out:
# fixed acidity          -0.113663
# volatile acidity       -0.194723
# citric acid            -0.009209
# residual sugar         -0.097577
# chlorides              -0.209934
# free sulfur dioxide     0.008158
# total sulfur dioxide   -0.174737
# density                -0.307123
# pH                      0.099427
# sulphates               0.053678
# alcohol                 0.435575
# quality                 1.000000
# Name: quality, dtype: float64

# %%
pollution = pd.read_csv(os.path.join('data', 'pollution_data.csv'))

# %%
proper_dates = pd.to_datetime(pollution.when.values)
index = pd.MultiIndex.from_tuples(list(zip(proper_dates.year, proper_dates.month, proper_dates.day)),
                                 names=['Year', 'Month','Day'])

# %%
quantitative = pd.DataFrame(
    {'station': pollution.station.values,
     'magnitude': pollution.magnitude.values,
     'measurement': pollution.measurement.values},
    index=index
)


filtered = quantitative[(quantitative.station == 'Cuatro Caminos') & (quantitative.magnitude == 'SO2')]

def pollution_evolution(df):
    for year in set(df.index.get_level_values('Year')):
        yield (df.loc[year, 1].measurement.mean(),
               df.loc[year, 1].measurement.max(),
               df.loc[year, 1].measurement.min(),
               pd.Timestamp(year, 1, 31))
        
df = pd.DataFrame.from_records(pollution_evolution(filtered), columns=['mean', 'max', 'min', 'year'])

# %%
df.set_index = df.year

# %%
df.index
# Out:
# RangeIndex(start=0, stop=16, step=1)
